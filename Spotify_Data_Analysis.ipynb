# %%
# Spotify Data Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks=pd.read_csv('SpotifyFeatures.csv')

# %%
df_tracks.head(6)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
# 5  Movie     Henri Salvador    Le petit souper aux chandelles
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
# 5  0Mf1jKa8eNAf1a4PwTbizj           0         0.749         0.578
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373  0.9100             0.000  C#    0.3460    -1.828  Major
# 1       137373  0.7370             0.000  F#    0.1510    -5.559  Minor
# 2       170267  0.1310             0.000   C    0.1030   -13.879  Minor
# 3       152427  0.3260             0.000  C#    0.0985   -12.178  Major
# 4        82625  0.2250             0.123   F    0.2020   -21.150  Major
# 5       160627  0.0948             0.000  C#    0.1070   -14.970  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390
# 5       0.1430   87.479            4/4    0.358

# %%
# checking for null values
pd.isnull(df_tracks)
# Out:
#         genre  artist_name  track_name  track_id  popularity  acousticness  \
# 0       False        False       False     False       False         False
# 1       False        False       False     False       False         False
# 2       False        False       False     False       False         False
# 3       False        False       False     False       False         False
# 4       False        False       False     False       False         False
# ...       ...          ...         ...       ...         ...           ...
# 232720  False        False       False     False       False         False
# 232721  False        False       False     False       False         False
# 232722  False        False       False     False       False         False
# 232723  False        False       False     False       False         False
# 232724  False        False       False     False       False         False
#
#         danceability  duration_ms  energy  instrumentalness    key  liveness  \
# 0              False        False   False             False  False     False
# 1              False        False   False             False  False     False
# 2              False        False   False             False  False     False
# 3              False        False   False             False  False     False
# 4              False        False   False             False  False     False
# ...              ...          ...     ...               ...    ...       ...
# 232720         False        False   False             False  False     False
# 232721         False        False   False             False  False     False
# 232722         False        False   False             False  False     False
# 232723         False        False   False             False  False     False
# 232724         False        False   False             False  False     False
#
#         loudness   mode  speechiness  tempo  time_signature  valence
# 0          False  False        False  False           False    False
# 1          False  False        False  False           False    False
# 2          False  False        False  False           False    False
# 3          False  False        False  False           False    False
# 4          False  False        False  False           False    False
# ...          ...    ...          ...    ...             ...      ...
# 232720     False  False        False  False           False    False
# 232721     False  False        False  False           False    False
# 232722     False  False        False  False           False    False
# 232723     False  False        False  False           False    False
# 232724     False  False        False  False           False    False
#
# [232725 rows x 18 columns]

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %%
# top 10 least popular songs on Spotify
leastpopular_df_tracks=df_tracks.sort_values('popularity',ascending=True).head(11)
leastpopular_df_tracks
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
# 74967  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# 74961                              Breeze  6v126eNn1A79yFIKGfvqLz           0
# 74962                            Woodland  7qR2PWbDeuhh1Vzd0anb25           0
# 74963              Cool Me - Instrumental  0V3Q9RYUaiLKTJIvg4KCST           0
# 74964           The Tortoise and the Hare  0oX193rf5y87RipsZnH8Pq           0
# 56153                     Lié par le sang  3GO9Wo14FvMXvOKE4LItjg           0
# 74966                            Forsaken  1rRNU87xfqvxiUsEXXyi8k           0
# 74967                 By the Swanee River  1rVdSGC2sqSQYbtgTUHrfi           0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0            0.6110         0.389        99373  0.9100          0.000000  C#
# 74954        0.1390         0.556       150487  0.4390          0.006400   D
# 74958        0.2130         0.736       212547  0.4460          0.821000   D
# 74959        0.0131         0.639       184000  0.8440          0.095700  A#
# 74961        0.0280         0.607       147653  0.5540          0.000000   A
# 74962        0.9950         0.529       266067  0.1540          0.414000   B
# 74963        0.2500         0.623       350080  0.4710          0.931000  A#
# 74964        0.4960         0.563       201362  0.3460          0.000000   D
# 56153        0.0294         0.656       276027  0.6940          0.000017   A
# 74966        0.9940         0.429       129387  0.0382          0.000000   B
# 74967        0.9950         0.606       263813  0.4500          0.448000   E
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0        0.3460    -1.828  Major       0.0525  166.969            4/4    0.814
# 74954    0.1720   -11.604  Major       0.0288  165.306            4/4    0.820
# 74958    0.2980   -12.328  Major       0.0504  130.011            4/4    0.668
# 74959    0.0399    -8.582  Minor       0.0439  120.027            4/4    0.271
# 74961    0.1690   -10.571  Major       0.3710   92.193            4/4    0.404
# 74962    0.1230    -9.222  Minor       0.0470   69.588            4/4    0.332
# 74963    0.2580    -8.675  Major       0.0332  120.015            4/4    0.515
# 74964    0.1200   -14.058  Major       0.0938  144.642            4/4    0.370
# 56153    0.0527    -6.755  Major       0.0273  120.085            4/4    0.449
# 74966    0.4480   -12.704  Major       0.0557  156.807            3/4    0.474
# 74967    0.0666    -3.031  Minor       0.1380  101.845            4/4    0.730

# %%
import altair as alt
alt.Chart(leastpopular_df_tracks).mark_line().encode(
    x='acousticness',
    y='danceability'
)
# Out:
# alt.Chart(...)

# %%
import matplotlib.pyplot as plt
leastpopular_df_tracks.hist()
plt.show()
# Displaying a histogram of all numerical columns in the dataframe.

# %%
# most popular songs on Spotify
most_popular_tracks=df_tracks.query('popularity>90',inplace=False).sort_values('popularity',ascending=True)
most_popular_tracks[:10]
# Out:
#             genre    artist_name                  track_name  \
# 86973         Rap    Post Malone  rockstar (feat. 21 Savage)
# 107910        Pop          Mabel            Don't Call Me Up
# 107826        Pop        Cardi B                   Please Me
# 66614     Hip-Hop        Mustard     Pure Water (with Migos)
# 66617     Hip-Hop   XXXTENTACION                   Moonlight
# 66750     Hip-Hop   Daddy Yankee                    Adictiva
# 138931  Reggaeton   Daddy Yankee                    Adictiva
# 107911        Pop  Lewis Capaldi           Someone You Loved
# 107832        Pop        Mustard     Pure Water (with Migos)
# 152287        R&B          Mabel            Don't Call Me Up
#
#                       track_id  popularity  acousticness  danceability  \
# 86973   0e7ipj03S05BNilyu5bRzt          91        0.1170         0.587
# 107910  5WHTFyqSii0lmT9R21abT8          91        0.2960         0.674
# 107826  0PG9fbaaHFHfre2gUVo7AN          91        0.0642         0.747
# 66614   63cd4JkwGgYJrbOizbfmsp          91        0.1720         0.680
# 66617   0JP9xo3adEtGSdUEISiszL          91        0.5560         0.921
# 66750   6MJUCumnQsQEKbCy28tbCP          91        0.2910         0.788
# 138931  6MJUCumnQsQEKbCy28tbCP          91        0.2910         0.788
# 107911  2TIlqbIneP0ZY1O0EzYLlc          91        0.7510         0.501
# 107832  63cd4JkwGgYJrbOizbfmsp          91        0.1720         0.680
# 152287  5WHTFyqSii0lmT9R21abT8          91        0.2960         0.674
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 86973        218147   0.535          0.000066   F    0.1310    -6.090  Minor
# 107910       178480   0.881          0.000003   A    0.0793    -2.853  Major
# 107826       200890   0.570          0.000000  C#    0.0832    -6.711  Major
# 66614        194520   0.559          0.000000   C    0.3180    -5.545  Major
# 66617        135090   0.537          0.004040   A    0.1020    -5.723  Minor
# 66750        207853   0.771          0.000056   E    0.1720    -3.206  Minor
# 138931       207853   0.771          0.000056   E    0.1720    -3.206  Minor
# 107911       182161   0.405          0.000000  C#    0.1050    -5.679  Major
# 107832       194520   0.559          0.000000   C    0.3180    -5.545  Major
# 152287       178480   0.881          0.000003   A    0.0793    -2.853  Major
#
#         speechiness    tempo time_signature  valence
# 86973        0.0898  159.847            4/4    0.140
# 107910       0.1470   98.994            4/4    0.234
# 107826       0.0810  133.992            4/4    0.650
# 66614        0.1290  202.006            4/4    0.137
# 66617        0.0804  128.009            4/4    0.711
# 66750        0.0563   99.038            4/4    0.701
# 138931       0.0563   99.038            4/4    0.701
# 107911       0.0319  109.891            4/4    0.446
# 107832       0.1290  202.006            4/4    0.137
# 152287       0.1470   98.994            4/4    0.234

# %%
# changing time duration of music to seconds
df_tracks['duration']=df_tracks['duration_ms'].apply(lambda x:round(x/1000))
df_tracks.drop('duration_ms',inplace=True,axis=1)

# %%
df_tracks.duration.head(6)
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# 5    161
# Name: duration, dtype: int64

# %%
sample_df=df_tracks.sample(int(0.004*len(df_tracks)))
print(len(df_tracks))
# Out:
# 232725

# %%
# Correlation between Loudness and Energy in Music
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y='loudness',x='energy',color='c').set(title='Loudness vs Energy')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy')]

# %%
dataframe = pd.read_csv('SpotifyFeatures.csv')
dataframe.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
dataframe.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.385000          0.000000       0.097400     -11.771000
# 50%         0.605000          0.000044       0.128000      -7.762000
# 75%         0.787000          0.035800       0.264000      -5.501000
# max         0.999000          0.999000       1.000000       3.744000
#
#          speechiness          tempo        valence
# count  232725.000000  232725.000000  232725.000000
# mean        0.120765     117.666585       0.454917
# std         0.185518      30.898907       0.260065
# min         0.022200      30.379000       0.000000
# 25%         0.036700      92.959000       0.237000
# 50%         0.050100     115.778000       0.444000
# 75%         0.105000     139.054000       0.660000
# max         0.967000     242.903000       1.000000

# %%
print(dataframe.keys())
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
list_of_keys = dataframe['key'].unique()
for i in range(len(list_of_keys)):
    dataframe.loc[dataframe['key'] == list_of_keys[i], 'key'] = i
dataframe.sample(5)
# Out:
#         genre     artist_name                        track_name  \
# 105904  Opera    Robert Stolz  Two Hearts In Three-Quarter Time
# 224662   Rock     The Strokes               What Ever Happened?
# 144944  Indie  Sinead Harnett                           Lessons
# 151393    Pop     Regulo Caro                El Lujo De Tenerte
# 178337   Jazz    Norman Brown               For The Love Of You
#
#                       track_id  popularity  acousticness  danceability  \
# 105904  5cvvak7fzproMt44KT5tST           6      0.958000         0.252
# 224662  78Gzxi27GuNHTfkn2BylG4          56      0.000097         0.547
# 144944  61gMPDC1BYxaTFu3af2IBK          54      0.448000         0.545
# 151393  0bIBXi8kSiEkJhlCgg286I          66      0.331000         0.725
# 178337  7jBTGJNv5gggE4oiV1qKmY          32      0.428000         0.712
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 105904       177067   0.155            0.7720   4    0.1060   -15.221  Major
# 224662       169273   0.599            0.6790  11    0.2290    -6.057  Major
# 144944       226449   0.509            0.0000   5    0.3360    -7.782  Major
# 151393       176403   0.451            0.0000   7    0.0914    -7.863  Minor
# 178337       321733   0.553            0.0565  11    0.1570   -10.262  Minor
#
#         speechiness    tempo time_signature  valence
# 105904       0.0401  135.492            4/4   0.0726
# 224662       0.0344  116.165            4/4   0.5870
# 144944       0.2560  118.090            5/4   0.5590
# 151393       0.0334  129.987            4/4   0.6130
# 178337       0.0274   99.921            4/4   0.7850

# %%
dataframe.loc[dataframe["mode"] == 'Major', "mode"] = 1
dataframe.loc[dataframe["mode"] == 'Minor', "mode"] = 0
dataframe.sample(5)
# Out:
#              genre               artist_name  \
# 45379        Anime              Hikaru Utada
# 157941         Ska  Big D and the Kids Table
# 143417       Indie                  Day Wave
# 207003  Soundtrack               Hans Zimmer
# 931        Country            Restless Heart
#
#                                      track_name                track_id  \
# 45379                                      嵐の女神  7dFI4D5UgAxt2q4sk5Vr8V
# 157941                                   Bender  5iQpHNxyiLaYa9LSMyFoa9
# 143417                             Total Zombie  2r7JYb8F8IrS5n9RO1jPPo
# 207003                        The Peleliu Hills  1DYeGB4Q2pIHSFuszFuMJM
# 931     Why Does It Have to Be (Wrong or Right)  0IdSezptoRChPUve2I2fEM
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 45379           19        0.8690         0.516       256267  0.4740
# 157941          29        0.0222         0.541       216027  0.9750
# 143417          46        0.3250         0.563       255506  0.8420
# 207003          25        0.7100         0.160       277693  0.0561
# 931             41        0.2440         0.752       179373  0.4880
#
#         instrumentalness key  liveness  loudness mode  speechiness    tempo  \
# 45379           0.000023   3    0.0986    -7.060    1       0.0242   80.008
# 157941          0.000000   4    0.0993    -1.566    1       0.0498  156.887
# 143417          0.293000   5    0.1570    -8.011    1       0.0284  149.001
# 207003          0.937000  10    0.1190   -23.249    0       0.0427  131.648
# 931             0.000000  10    0.0491   -11.498    1       0.0263   88.945
#
#        time_signature  valence
# 45379             4/4   0.3460
# 157941            4/4   0.9190
# 143417            4/4   0.7290
# 207003            4/4   0.0342
# 931               4/4   0.8040

# %%
list_of_time_signatures = dataframe['time_signature'].unique()
for i in range(len(list_of_time_signatures)):
    dataframe.loc[dataframe['time_signature'] == list_of_time_signatures[i], 'time_signature'] = i
dataframe.sample(5)
# Out:
#             genre      artist_name  \
# 91245     Hip-Hop    Rexx Life Raj
# 86294         R&B   Meghan Trainor
# 165548  Reggaeton        DrefQuila
# 80690       Opera  Giacomo Puccini
# 59769         R&B              SZA
#
#                                                track_name  \
# 91245                                     Waiting for You
# 86294                                      Throwback Love
# 165548                                     Seguir o parar
# 80690   Madama Butterfly, Act II: Io scendo al piano (...
# 59769                                      Sweet November
#
#                       track_id  popularity  acousticness  danceability  \
# 91245   3PgmQl12KXQofJDeBROKcU          51        0.8280         0.774
# 86294   3xTHJOM0ZxiEaCjpTfjeF0          47        0.0469         0.551
# 165548  0CywAU9Yjgzfg8ZcNtEIjO          37        0.4640         0.687
# 80690   29HrdLn0HZs46gWzHfJx33          16        0.9810         0.225
# 59769   7swGurTfZlwx7mTOE8PpIc          53        0.5320         0.478
#
#         duration_ms  energy  instrumentalness key  liveness  loudness mode  \
# 91245        211470  0.6310          0.000291   1    0.1310   -10.121    1
# 86294        193853  0.8560          0.000001  11    0.0926    -2.758    0
# 165548       183080  0.5030          0.000000   1    0.1700   -13.072    0
# 80690         96907  0.0996          0.006880   2    0.3900   -14.915    1
# 59769        243744  0.5510          0.015400   2    0.2880    -7.079    0
#
#         speechiness    tempo time_signature  valence
# 91245        0.1190  127.979              0   0.6410
# 86294        0.1730  192.126              0   0.6640
# 165548       0.2610  170.042              0   0.6750
# 80690        0.0372   79.448              3   0.0766
# 59769        0.0354  108.849              0   0.4810

# %%
dataframe.loc[dataframe['popularity'] < 57, 'popularity'] = 0
dataframe.loc[dataframe['popularity'] >= 57, 'popularity'] = 1
dataframe.loc[dataframe['popularity'] == 1]
# Out:
#        genre     artist_name  \
# 135      R&B   Mary J. Blige
# 136      R&B         Rihanna
# 137      R&B       Yung Bleu
# 138      R&B        Surfaces
# 139      R&B  Olivia O'Brien
# ...      ...             ...
# 230312  Soul     James Brown
# 230782  Soul    Alex Hepburn
# 230817  Soul    Paloma Faith
# 230946  Soul     James Brown
# 231493  Soul      Simply Red
#
#                                                track_name  \
# 135                            Be Without You - Kendu Mix
# 136                                             Desperado
# 137            Ice On My Baby (feat. Kevin Gates) - Remix
# 138                             Heaven Falls / Fall on Me
# 139                                           Love Myself
# ...                                                   ...
# 230312  Get Up (I Feel Like Being A) Sex Machine - Pts...
# 230782                                        If You Stay
# 230817                        Make Your Own Kind of Music
# 230946                 Papa's Got A Brand New Bag - Pt. 1
# 231493                             The Air That I Breathe
#
#                       track_id  popularity  acousticness  danceability  \
# 135     2YegxR5As7BeQuVp2U6pek           1       0.08300         0.724
# 136     6KFaHC9G178beAp7P0Vi5S           1       0.32300         0.685
# 137     6muW8cSjJ3rusKJ0vH5olw           1       0.06750         0.762
# 138     7yHqOZfsXYlicyoMt62yC6           1       0.36000         0.563
# 139     4XzgjxGKqULifVf7mnDIQK           1       0.59600         0.653
# ...                        ...         ...           ...           ...
# 230312  6hpmTwgNCz81H2bFEREx29           1       0.27300         0.833
# 230782  4sJoIeb8zWYCLHSLM0az3b           1       0.04530         0.719
# 230817  5jsFFhABp2FkasGr4QcQd6           1       0.00862         0.567
# 230946  5aZzmPUv5a2nna9sxBrmpL           1       0.51900         0.775
# 231493  4Sfq2ZuUK9tS66eXqCCKRF           1       0.21000         0.660
#
#         duration_ms  energy  instrumentalness key  liveness  loudness mode  \
# 135          246333   0.689          0.000000   8    0.3040    -5.922    0
# 136          186467   0.610          0.000000   2    0.1020    -5.221    0
# 137          199520   0.520          0.000004   3    0.1140    -5.237    0
# 138          240597   0.366          0.002430  11    0.0955    -6.896    0
# 139          213947   0.621          0.000000  11    0.0811    -5.721    0
# ...             ...     ...               ...  ..       ...       ...  ...
# 230312       318800   0.661          0.000149   9    0.2940    -7.595    0
# 230782       194554   0.702          0.000013  11    0.0662    -4.577    1
# 230817       163840   0.753          0.001830   5    0.1270    -4.823    1
# 230946       128973   0.725          0.054100   5    0.0944    -8.369    1
# 231493       262827   0.560          0.000040   2    0.0974    -8.894    1
#
#         speechiness    tempo time_signature  valence
# 135          0.1350  146.496              0   0.6930
# 136          0.0439   94.384              2   0.3230
# 137          0.0959   75.047              0   0.0862
# 138          0.1210   85.352              0   0.7680
# 139          0.0409  100.006              0   0.4660
# ...             ...      ...            ...      ...
# 230312       0.1010  108.314              0   0.8580
# 230782       0.0357  116.938              0   0.6130
# 230817       0.0406  120.098              0   0.5660
# 230946       0.0944  129.681              0   0.9140
# 231493       0.0287   89.505              0   0.6410
#
# [49104 rows x 18 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness",
            "mode", "speechiness", "tempo", "time_signature", "valence"]

# %%
training = dataframe.sample(frac = 0.8,random_state = 420)
X_train = training[features]
y_train = training['popularity']
X_test = dataframe.drop(training.index)[features]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %%
# Logistic Regression Implementation
LR_Model = LogisticRegression()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict)
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.7895316360511333
# AUC: 0.5

# %%
# Random Forest Implementation
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict)
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.9214738425179934
# AUC: 0.8334762319384573

# %%
df_genre=pd.read_csv('SpotifyFeatures.csv')
df_genre.head(6)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
# 5  Movie     Henri Salvador    Le petit souper aux chandelles
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
# 5  0Mf1jKa8eNAf1a4PwTbizj           0         0.749         0.578
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373  0.9100             0.000  C#    0.3460    -1.828  Major
# 1       137373  0.7370             0.000  F#    0.1510    -5.559  Minor
# 2       170267  0.1310             0.000   C    0.1030   -13.879  Minor
# 3       152427  0.3260             0.000  C#    0.0985   -12.178  Major
# 4        82625  0.2250             0.123   F    0.2020   -21.150  Major
# 5       160627  0.0948             0.000  C#    0.1070   -14.970  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390
# 5       0.1430   87.479            4/4    0.358

# %%
plt.title('Duration of the Songs in Various Genres')
sns.color_palette('rocket',as_cmap=True)
sns.barplot(y='genre',x='duration_ms',data=df_genre)
plt.xlabel('Duration in Milli Seconds')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %%
sns.set_style(style='darkgrid')
plt.figure(figsize=(7,3))
famous=df_genre.sort_values('popularity',ascending=False).head(10)
sns.barplot(y='genre',x='popularity',data=famous).set(title='Top 5 Genres by Popularity')
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]
